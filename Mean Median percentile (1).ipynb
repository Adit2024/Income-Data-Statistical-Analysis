# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import warnings
warnings.filterwarnings("ignore")

df = pd.read_excel(r"C:\Users\HP\Downloads\income.csv.xlsx")

df.head(7)
# Out:
#    S.NO.      name     income
# 0      0        Rob      5000
# 1      1      Rafiq      6000
# 2      2       Nina      4000
# 3      3      Sofia      7500
# 4      4      Mohan      8000
# 5      5        Tao      7000
# 6      6  Elon Musk  10000000

# %%
df.income.describe()
# Out:
# count    7.000000e+00
# mean     1.433929e+06
# std      3.777283e+06
# min      4.000000e+03
# 25%      5.500000e+03
# 50%      7.000000e+03
# 75%      7.750000e+03
# max      1.000000e+07
# Name: income, dtype: float64

# %%
int (df['income'].quantile(0))
# Out:
# 4000

# %%
int (df['income'].quantile(0.25, interpolation='higher'))
# Out:
# 6000

# %%
int (df['income'].quantile(0.5, interpolation='higher'))
# Out:
# 7000

# %%
int(df['income'].quantile(0.75, interpolation='higher'))
# Out:
# 8000

# %%
int(df['income'].quantile(1, interpolation='higher'))
# Out:
# 10000000

# %%
int (df['income'].quantile(0.99))
# Out:
# 9400479

# %%
df[df.income>percentile_99]
# Out:
#    S.NO.      name     income
# 6      6  Elon Musk  10000000

# %%
int (df['income'].mean())
# Out:
# 1433928

# %%
int (df['income'].median())
# Out:
# 7000

# %%
df['income'].std()
# Out:
# 3777282.714118835

# %%
df['income'].var()
# Out:
# 14267864702380.953

# %%
df['income'].min()
# Out:
# 4000

# %%
df['income'].max()
# Out:
# 10000000

# %%
df['income'].max() - df['income'].min()
# Out:
# 9996000

# %%
sns.histplot(df['income'], bins=10, kde=True)
plt.xlim(0, df['income'].quantile(1))
plt.show()
